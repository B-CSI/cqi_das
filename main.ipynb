# %%
# %load_ext autoreload
# %autoreload 2

from common import DUMMY, DATA_DIR
import utils as utl

# %%
pathname = DATA_DIR / "CANDAS/GC/20200815_19h05m"
utl.import_miniseed(pathname, 2020, "G")
# Out:
# Reading traces elapsed time:  0:00:08.757393
#             5          6      8      9      10     11     12     13     14    \
# 0       2.595000  -2.679000  0.167 -0.534  1.159  1.308  1.784 -1.190  0.659
# 1       5.284000  -9.186000  0.803 -0.037 -0.556  0.783  2.322 -0.938  0.322
# 2       2.253000 -11.490000 -0.228 -0.750 -1.748  1.060  2.128 -1.733  0.250
# 3      10.471000  -5.797000  0.204 -0.061 -0.935  0.409  2.323 -1.205  1.152
# 4      17.108999  -8.012000  0.428 -0.916  0.766 -0.210  1.745 -1.027  0.312
# ...          ...        ...    ...    ...    ...    ...    ...    ...    ...
# 31243 -48.645000 -65.022003  2.101  2.149 -0.299  0.626 -0.200 -0.250  0.935
# 31244 -37.847000 -60.902000  1.933  1.555 -0.106 -0.835  0.485  0.438  0.113
# 31245 -25.058001 -66.358002  1.281  1.513  0.597  0.893  0.644 -0.179 -0.078
# 31246 -23.316000 -63.526001  2.060  2.193 -1.087 -0.262  0.864  0.456  0.319
# 31247 -25.579000 -59.862999  1.780  0.902  0.703 -0.084  0.535  0.378  0.594
#
# ...

# %%
pathname = DATA_DIR / "CANDAS2"
utl.import_h5(pathname, 'CANDAS2_2022-12-27_07-46-15.h5')
# Out:
# array([[  11143.296,   11136.528,   11141.208, ...,    7070.544,
#            7070.328,    7066.656],
#        [   6795.216,    6804.36 ,    6794.856, ...,    5820.48 ,
#            5820.264,    5825.52 ],
#        [  13179.96 ,   13176.504,   13184.064, ...,   12788.568,
#           12788.712,   12797.64 ],
#        ...,
#        [-439681.03 , -439709.84 , -439705.16 , ..., -440349.84 ,
#         -440355.03 , -440331.06 ],
#        [-467009.44 , -466982.12 , -467013.16 , ..., -468792.38 ,
#         -468835.12 , -468872.06 ],
#        [-500124.03 , -500154.25 , -500159.38 , ..., -500975.72 ,
#         -500955.4  , -501009.9  ]], dtype=float32)
